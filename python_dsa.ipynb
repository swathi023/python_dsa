# %%
#day01_python_dsa.py

# %%
# Day 01 Practice

# 1. Print
print("Hello, this is my Day 01 on GitHub")

# 2. Variables
name = "Swathi"
age = 20
cgpa = 7.5

print(name, age, cgpa)

# 3. Even or Odd
n = int(input("Enter a number: "))
if n % 2 == 0:
    print("Even")
else:
    print("Odd")

# 4. Sum of N numbers
n = int(input("Enter n: "))
sum = 0
for i in range(1, n+1):
    sum += i

print("Sum is:", sum)
# Out:
# Hello, this is my Day 01 on GitHub
# Swathi 20 7.5
# Enter a number: 23
# Odd
# Enter n: 21
# Sum is: 231
